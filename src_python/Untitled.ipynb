# %%
import os ,sys
import numpy as np
import pandas as pd

# %%
ls make_movie/
# Out:
# __pycache__/         make_shogi_movie.py  plot_board.py
# images/              piece.py             util.py

# %%
from make_movie.plot_board import Plot

# %%
from shogi_api.board import Board

# %%
b = Board()
# Out:
# ['1716', '2726', '3736', '4746', '5756', '6766', '7776', '8786', '9796', '2838', '2848', '2858', '2868', '2878', '2818', '1918', '3938', '3948', '4938', '4948', '4958', '5948', '5958', '5968', '6958', '6968', '6978', '7968', '7978', '9998']
# ...
# 99
# 0.00027179718017578125
# 0.029796123504638672

# %%
b.all_pieces
# Out:
# {'hand': {'gote': {'FU': 0,
#    'GI': 0,
#    'HI': 0,
#    'KA': 0,
#    'KE': 0,
#    'KI': 0,
#    'KY': 0},
#   'sente': {'FU': 0, 'GI': 0, 'HI': 0, 'KA': 0, 'KE': 0, 'KI': 0, 'KY': 0}},
#  'main': {'11': <shogi_api.piece.Piece at 0x11365b710>,
#   '12': None,
#   '13': <shogi_api.piece.Piece at 0x11365bd68>,
#   '14': None,
#   '15': None,
#   '16': None,
#   '17': <shogi_api.piece.Piece at 0x113656780>,
#   '18': None,
#   '19': <shogi_api.piece.Piece at 0x113656dd8>,
#   '21': <shogi_api.piece.Piece at 0x11365b780>,
#   '22': <shogi_api.piece.Piece at 0x11365bb38>,
#   '23': <shogi_api.piece.Piece at 0x11365bdd8>,
#   '24': None,
#   '25': None,
#   '26': None,
#   '27': <shogi_api.piece.Piece at 0x1136567f0>,
#   '28': <shogi_api.piece.Piece at 0x113656ba8>,
#   '29': <shogi_api.piece.Piece at 0x113656e48>,
#   '31': <shogi_api.piece.Piece at 0x11365b7f0>,
#   '32': None,
#   '33': <shogi_api.piece.Piece at 0x11365be48>,
#   '34': None,
#   '35': None,
#   '36': None,
# ...

# %%
p = Plot(b)

# %%
p.plot_all()

# %%
p.board.all_pieces
# Out:
# {'hand': {'gote': {'FU': 0,
#    'GI': 0,
#    'HI': 0,
#    'KA': 0,
#    'KE': 0,
#    'KI': 0,
#    'KY': 0},
#   'sente': {'FU': 0, 'GI': 0, 'HI': 0, 'KA': 0, 'KE': 0, 'KI': 0, 'KY': 0}},
#  'main': {'11': <shogi_api.piece.Piece at 0x11365b710>,
#   '12': None,
#   '13': <shogi_api.piece.Piece at 0x11365bd68>,
#   '14': None,
#   '15': None,
#   '16': None,
#   '17': <shogi_api.piece.Piece at 0x113656780>,
#   '18': None,
#   '19': <shogi_api.piece.Piece at 0x113656dd8>,
#   '21': <shogi_api.piece.Piece at 0x11365b780>,
#   '22': <shogi_api.piece.Piece at 0x11365bb38>,
#   '23': <shogi_api.piece.Piece at 0x11365bdd8>,
#   '24': None,
#   '25': None,
#   '26': None,
#   '27': <shogi_api.piece.Piece at 0x1136567f0>,
#   '28': <shogi_api.piece.Piece at 0x113656ba8>,
#   '29': <shogi_api.piece.Piece at 0x113656e48>,
#   '31': <shogi_api.piece.Piece at 0x11365b7f0>,
#   '32': None,
#   '33': <shogi_api.piece.Piece at 0x11365be48>,
#   '34': None,
#   '35': None,
#   '36': None,
# ...
