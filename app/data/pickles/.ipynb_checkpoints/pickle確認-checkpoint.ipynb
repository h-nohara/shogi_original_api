# %%
import os, sys, pickle

# %%
with open("./now.pickle", "rb") as f:
    result = pickle.load(f)

# %%
history = result["history"]

# %%
history
# Out:
# [{'board_state': {'all_pieces': {'hand': {'gote': {'FU': 0,
#       'GI': 0,
#       'HI': 0,
#       'KA': 0,
#       'KE': 0,
#       'KI': 0,
#       'KY': 0},
#      'sente': {'FU': 0, 'GI': 0, 'HI': 0, 'KA': 0, 'KE': 0, 'KI': 0, 'KY': 0}},
#     'main': {'11': {'is_sente': False, 'loc': '11', 'name': 'KY'},
#      '12': None,
#      '13': {'is_sente': False, 'loc': '13', 'name': 'FU'},
#      '14': None,
#      '15': None,
#      '16': None,
#      '17': {'is_sente': True, 'loc': '17', 'name': 'FU'},
#      '18': None,
#      '19': {'is_sente': True, 'loc': '19', 'name': 'KY'},
#      '21': {'is_sente': False, 'loc': '21', 'name': 'KE'},
#      '22': {'is_sente': False, 'loc': '22', 'name': 'KA'},
#      '23': {'is_sente': False, 'loc': '23', 'name': 'FU'},
#      '24': None,
#      '25': None,
#      '26': None,
#      '27': {'is_sente': True, 'loc': '27', 'name': 'FU'},
#      '28': {'is_sente': True, 'loc': '28', 'name': 'HI'},
# ...

# %%
for action in history:
    print(action["move"])
# Out:
# initial
# 7776
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-cfd0a80c99ee> in <module>()
#       1 for action in history:
# ----> 2     print(action["move"])
#
# KeyError: 'move'

# %%
for i in range(2):
    print("===========--")
    for action in history[2]["scenarios"][1][-1]["scenarios"][i]:
        print(action["board_state"]["legal_moves"])
        print()
# Out:
# ===========--
# ['1716', '1918', '2726', '3736', '3928', '3938', '3948', '4746', '4938', '4948', '4958', '5756', '5948', '5958', '5968', '6766', '6958', '6968', '7675', '7868', '7858', '7848', '7838', '7828', '7818', '7968', '8786', '8877', '8866', '8855', '8844', '8833', '8833+', '8822', '8822+', '8977', '9796', '9998']
#
# ['1112', '1314', '2133', '2233', '2244', '2255', '2266', '2277', '2277+', '2288', '2288+', '2324', '3132', '3142', '3435', '4132', '4142', '4152', '4344', '5142', '5152', '5162', '5354', '6152', '6162', '6172', '6364', '7162', '7172', '7374', '8292', '8272', '8262', '8252', '8242', '8232', '8283', '8485', '9192', '9394']
#
# ['1716', '1918', '2726', '3736', '3928', '3938', '3948', '4746', '4938', '4948', '4958', '5756', '5948', '5958', '5968', '6766', '6958', '6968', '7574', '7888', '7868', '7858', '7848', '7838', '7828', '7818', '7968', '7988', '8786', '8977', '9796', '9998']
#
# ...

# %%
history[0]["board_state"].keys()

# %%
b = history[0]["board_state"]

# %%
b["legal_moves"]

# %%
b
